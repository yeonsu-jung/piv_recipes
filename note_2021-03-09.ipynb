# %%
import openpiv_recipes as piv
import importlib
import numpy as np
import os
import time

from matplotlib import pyplot as plt

t = time.time()
importlib.reload(piv)
# Out:
# <module 'openpiv_recipes' from '/Users/yeonsu/Documents/github/piv_recipes/openpiv_recipes.py'>

# %%
folder_path = '/Users/yeonsu/Dropbox (Harvard University)/Riblet/data/piv-data/2021-03-09'
results_folder_path = '/Users/yeonsu/Dropbox (Harvard University)/Riblet/data/piv-results'

# folder_path = "C:\\Users\\yj\\Dropbox (Harvard University)\\Riblet\\data\\piv-data\\2021-03-02"
# results_folder_path = 'C:\\Users\\yj\\Dropbox (Harvard University)\\Riblet\\data\\piv-results'

pi = piv.ParticleImage(folder_path,results_folder_path)

# %%
piv_cond = {
    "winsize": 28, "searchsize": 34, "overlap": 24,
    "pixel_density": 47,"scale_factor": 3e4, "arrow_width": 0.001,
    "u_bound": [-50,50],"v_bound": [-1000,0],
    "transpose": False, "crop": [0,0,0,0],    
    "sn_threshold": 1.000001,'dt': 0.0001,
    "rotate": 0.25, "save_result": True,"show_result": False
}
pi.set_piv_param(piv_cond)

# %%
sd = {'path': '0309_Exp03'}
ind = pi.check_proper_index(sd,index_a = 10)
dummy = pi.quick_piv(sd,index_a = ind, index_b = ind + 1)
# Out:
# Read image from: 0309_Exp03
# Read image from: 0309_Exp03
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 0, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: True
# Read image from: 0309_Exp03
# Number of invalid vectors: 0
# Mean of u: -2.414
# Std of u: 8.105
# Mean of v: -66.619
# Std of v: 8.850

# %%
paths = ['0309_Exp04', '0309_Exp05', '0309_Exp06', '0309_Exp07', '0309_Exp08', '0309_Exp09','0309_Exp10', '0309_Exp11','0309_Exp12',]

mean_u = []
std_u = []
mean_v = []
std_v = []
for x in paths:
    sd = {'path': x}
    ind = pi.check_proper_index(sd,index_a = 10)
    x,y,u,v = pi.quick_piv(sd,index_a = ind, index_b = ind + 1)
    mean_u.append(np.mean(u))
    std_u.append(np.std(u,ddof=1))
    mean_v.append(np.mean(v))
    std_v.append(np.std(v,ddof=1))
# Out:
# Read image from: 0309_Exp04
# Read image from: 0309_Exp04
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 0, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: True
# Read image from: 0309_Exp04
# Number of invalid vectors: 0
# Mean of u: -1.046
# Std of u: 7.311
# Mean of v: -60.139
# Std of v: 8.018
# Read image from: 0309_Exp05
# Read image from: 0309_Exp05
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# ...

# %%
plt.plot(mean_u,'o-')

# %%
x = np.array([0.083697044,0.170552467,0.258987079,0.345842502,0.434277114,0.522711727,0.60956715,0.699580952,0.778540427])*1000

# plt.errorbar(x,np.array(mean_v)*(-1),np.array(std_v),'o-')
plt.plot(x,np.array(mean_v)*(-1),'o-')
plt.xlabel('Flow meter value (mm/s)')
plt.ylabel('PIV value (mm/s)')
# Out:
# Text(0, 0.5, 'PIV value (mm/s)')

# %%
paths_thinner = ['0309_Exp13', '0309_Exp14', '0309_Exp15', '0309_Exp16', '0309_Exp17', '0309_Exp18','0309_Exp19', '0309_Exp20','0309_Exp21']

# %%
sd = {'path': '0309_Exp23'}
piv_cond = {
    "winsize": 28, "searchsize": 34, "overlap": 24,
    "pixel_density": 47,"scale_factor": 1e4, "arrow_width": 0.001,
    "u_bound": [-50,50],"v_bound": [-1000,0],
    "transpose": False, "crop": [0,0,350,0],    
    "sn_threshold": 1.000001,'dt': 0.0001,
    "rotate": 0.25, "save_result": True,"show_result": False
}
pi.set_piv_param(piv_cond)

ind = pi.check_proper_index(sd, 10)
dummy = pi.quick_piv(sd,index_a = ind, index_b = ind + 1)
# Out:
# Read image from: 0309_Exp23
# Read image from: 0309_Exp23
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 10000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 350, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: True
# Read image from: 0309_Exp23
# Number of invalid vectors: 0
# Mean of u: 3.259
# Std of u: 7.499
# Mean of v: -137.693
# Std of v: 20.121

# %%
sd = {'path': '0309_Exp13'}
piv_cond = {
    "winsize": 28, "searchsize": 34, "overlap": 24,
    "pixel_density": 47,"scale_factor": 1e4, "arrow_width": 0.001,
    "u_bound": [-50,50],"v_bound": [-1000,0],
    "transpose": False, "crop": [0,0,350,0],    
    "sn_threshold": 1.000001,'dt': 0.0001,
    "rotate": 0.25, "save_result": True,"show_result": False
}
pi.set_piv_param(piv_cond)

ind = pi.check_proper_index(sd, 10)
dummy = pi.quick_piv(sd,index_a = ind, index_b = ind + 1)

np.mean(dummy[3][30:50,20:40]), np.std(dummy[3][30:50,20:40])
# Out:
# Read image from: 0309_Exp13
# Read image from: 0309_Exp13
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 10000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 350, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: True
# Read image from: 0309_Exp13
# Number of invalid vectors: 0
# Mean of u: 1.070
# Std of u: 7.305
# Mean of v: -56.986
# Std of v: 14.333
# (-65.20551681316574, 8.224514750318255)

# %%
paths_thinner = ['0309_Exp13', '0309_Exp14', '0309_Exp15', '0309_Exp16', '0309_Exp17', '0309_Exp18','0309_Exp19', '0309_Exp20','0309_Exp21']

piv_cond = {
        "winsize": 28, "searchsize": 34, "overlap": 24,
        "pixel_density": 47,"scale_factor": 1e4, "arrow_width": 0.001,
        "u_bound": [-50,50],"v_bound": [-1000,0],
        "transpose": False, "crop": [0,0,350,0],    
        "sn_threshold": 1.000001,'dt': 0.0001,
        "rotate": 0.25, "save_result": True,"show_result": False
    }
pi.set_piv_param(piv_cond)

mean_freestream = []
std_freestream = []
for x in paths_thinner:
    sd = {'path': x}   
    ind = pi.check_proper_index(sd, 10)
    dummy = pi.quick_piv(sd,index_a = ind, index_b = ind + 1)

    mean_freestream.append(np.mean(dummy[3][30:50,20:40]))
    std_freestream.append(np.std(dummy[3][30:50,20:40]))
# Out:
# Read image from: 0309_Exp13
# Read image from: 0309_Exp13
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 10000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 350, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: True
# Read image from: 0309_Exp13
# Number of invalid vectors: 0
# Mean of u: 1.070
# Std of u: 7.305
# Mean of v: -56.986
# Std of v: 14.333
# Read image from: 0309_Exp14
# Read image from: 0309_Exp14
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 10000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# ...

# %%
paths_thicker = ['0309_Exp22', '0309_Exp23', '0309_Exp24', '0309_Exp25', '0309_Exp26', '0309_Exp27','0309_Exp28', '0309_Exp29','0309_Exp30']

piv_cond = {
        "winsize": 28, "searchsize": 34, "overlap": 24,
        "pixel_density": 47,"scale_factor": 1e4, "arrow_width": 0.001,
        "u_bound": [-50,50],"v_bound": [-1000,0],
        "transpose": False, "crop": [0,0,350,0],    
        "sn_threshold": 1.000001,'dt': 0.0001,
        "rotate": 0.25, "save_result": True,"show_result": False
    }
pi.set_piv_param(piv_cond)

mean_freestream = []
std_freestream = []
for x in paths_thicker:
    sd = {'path': x}   
    ind = pi.check_proper_index(sd, 10)
    dummy = pi.quick_piv(sd,index_a = ind, index_b = ind + 1)

    mean_freestream.append(np.mean(dummy[3][30:50,20:40]))
    std_freestream.append(np.std(dummy[3][30:50,20:40]))
# Out:
# Read image from: 0309_Exp22
# Read image from: 0309_Exp22
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 10000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 350, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: True
# Read image from: 0309_Exp22
# Number of invalid vectors: 0
# /Users/yeonsu/opt/anaconda3/envs/piv2/lib/python3.6/site-packages/numpy/core/fromnumeric.py:3373: RuntimeWarning: Mean of empty slice.
#   out=out, **kwargs)
# /Users/yeonsu/opt/anaconda3/envs/piv2/lib/python3.6/site-packages/numpy/core/_methods.py:170: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# Mean of u: 0.944
# Std of u: 7.593
# Mean of v: -62.130
# Std of v: 16.069
# ...

# %%
plt.plot(-np.array(mean_v),-np.array(mean_freestream),'o-')
plt.xlabel('Freestream velocity (mm/s) - from PIV w/o sample')
plt.ylabel('Freestream velocity (mm/s) - outside BL')
# Out:
# Text(0, 0.5, 'Freestream velocity (mm/s) - outside BL')

# %%
print(std_freestream)
# Out:
# [6.0396950854596065, 6.382397062636869, 7.844933825302822, 9.40662275337924, 10.074454747462307, 8.562489866386294, 7.604411867383276, 6.923225135512841, 8.307810700678946]

# %%
np.mean(dummy[3][30:50,40:60]), np.std(dummy[3][30:50,40:60])
# Out:
# (-609.0753143399737, 5.944802810784823)

# %%
print(dummy[0].shape, piv.peel_off_edges(dummy)[0].shape)
# Out:
# (52, 64) (50, 62)

# %%
temp = []

for i in range(40):
    temp.append(dummy[0][0][i])

plt.plot(temp,'o')

# %%
freestream = [60.1387,136.4204,205.4876,297.8346,391.2691,478.1023,570.8147,640.2341,700.4356]
outside_bl = [67.4,154.303,220.236,309.198,406.693,509.395,609.917,699.58,761.83]

plt.plot(freestream,outside_bl,'o-')
plt.xlabel('Freestream velocity (mm/s) - from PIV w/o sample')
plt.ylabel('Freestream velocity (mm/s) - outside BL')
# Out:
# Text(0, 0.5, 'Freestream velocity (mm/s) - outside BL')

# %%
piv_cond = {
    "winsize": 28, "searchsize": 34, "overlap": 24,
    "pixel_density": 47,"scale_factor": 3e4, "arrow_width": 0.001,
    "u_bound": [-50,50],"v_bound": [-550,0],
    "transpose": False, "show_result": False, "crop": [70,70,500,50],
    "sn_threshold": 1.000001,'dt': 0.0001,
    "rotate": 0.25, "save_result": False
}
pi.set_piv_param(piv_cond)

# %%
search_dict = {'path': x}
proper_index_a = pi.check_proper_index(search_dict,index_a = 3)
pi.piv_over_time(search_dict,start_index = proper_index_a,N = 95)
# Out:
# Read image from: 0309_Exp14
# Read image from: 0309_Exp14
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 0, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: True
# Read image from: 0309_Exp14
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-250-50ca6e7ec8a8> in <module>
#       1 search_dict = {'path': x}
#       2 proper_index_a = pi.check_proper_index(search_dict,index_a = 3)
# ----> 3 pi.piv_over_time(search_dict,start_index = proper_index_a,N = 95)
#
# ...

# %%
for x in paths_thinner:
    search_dict = {'path': x}    
    pi.point_statistics(search_dict,3,3,0.1)

# %%
piv_cond = {
    "winsize": 28, "searchsize": 34, "overlap": 24,
    "pixel_density": 47,"scale_factor": 3e4, "arrow_width": 0.001,
    "u_bound": [-50,50],"v_bound": [-1000,0],
    "transpose": False, "show_result": False, "crop": [0,0,350,0],
    "sn_threshold": 1.000001,'dt': 0.0001,
    "rotate": 0.25, "save_result": False
}
pi.set_piv_param(piv_cond)

search_dict = {'path': '0309_Exp17'}
proper_index_a = pi.check_proper_index(search_dict,index_a = 3)
pi.piv_over_time(search_dict,start_index = proper_index_a,N = 95)
# Out:
# tors: 0
# Mean of u: 9.898
# Std of u: 8.766
# Mean of v: -409.084
# Std of v: 30.483
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 350, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0309_Exp17
# Number of invalid vectors: 0
# Mean of u: 0.464
# Std of u: 6.909
# Mean of v: -402.968
# Std of v: 33.394
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# ...

# %%
# Out:
# /Users/yeonsu/Dropbox (Harvard University)/Riblet/data/piv-results/2021-03-09/0309_Exp17/entire_U.txt
# # Array shape: (52, 64)

# %%
piv_cond = {
    "winsize": 28, "searchsize": 34, "overlap": 24,
    "pixel_density": 47,"scale_factor": 3e4, "arrow_width": 0.001,
    "u_bound": [-50,50],"v_bound": [-1000,0],
    "transpose": False, "show_result": False, "crop": [0,0,350,0],
    "sn_threshold": 1.000001,'dt': 0.0001,
    "rotate": 0.25, "save_result": False
}
pi.set_piv_param(piv_cond)

search_dict = {'path': '0309_Exp26'}
proper_index_a = pi.check_proper_index(search_dict,index_a = 3)
pi.piv_over_time(search_dict,start_index = proper_index_a,N = 95)    
pi.point_statistics(search_dict,3,3,1)
# Out:
# lap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 350, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0309_Exp26
# Number of invalid vectors: 0
# Mean of u: 8.156
# Std of u: 12.168
# Mean of v: -405.763
# Std of v: 31.900
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 350, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0309_Exp26
# ...
