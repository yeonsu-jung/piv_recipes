# %%
import openpiv_recipes as piv
import importlib
import numpy as np
importlib.reload(piv)
# Out:
# <module 'openpiv_recipes' from 'c:\\Users\\yj\\Documents\\GitHub\\piv_recipes\\openpiv_recipes.py'>

# %%
# folder_path = '/Users/yeonsu/Dropbox (Harvard University)/Riblet/data/piv-data/2021-03-02'
# results_folder_path = '/Users/yeonsu/Dropbox (Harvard University)/Riblet/data/piv-results'

folder_path = "C:\\Users\\yj\\Dropbox (Harvard University)\\Riblet\\data\\piv-data\\2021-03-02"
results_folder_path = 'C:\\Users\\yj\\Dropbox (Harvard University)\\Riblet\\data\\piv-results'

pi = piv.ParticleImage(folder_path,results_folder_path)

# %%
search_dict = {'path': '0302_Exp31'}
proper_index_a = pi.check_proper_index(search_dict,index_a = 3)
# Out:
# Read image from: 0302_Exp31
# Read image from: 0302_Exp31

# %%
piv_cond = {
    "winsize": 28, "searchsize": 34, "overlap": 24,
    "pixel_density": 47,"scale_factor": 3e4, "arrow_width": 0.001,
    "u_bound": [-50,50],"v_bound": [-1000,0],
    "transpose": False, "show_result": False, "crop": [0,0,408,0],
    "sn_threshold": 1.000001,'dt': 0.0003,
    "rotate": 0.25, "save_result": False
}
pi.set_piv_param(piv_cond)

N = 2

ind = proper_index_a
entire_U = []
entire_V = []

for i in range(N):
    x,y,U,V = pi.quick_piv(search_dict,index_a = ind,index_b = ind+1)
    entire_U.append(U)
    entire_V.append(V)
    ind = ind + 2
# Out:
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -1.593
# Std of u: 6.751
# Mean of v: -443.946
# Std of v: 72.566
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 0.531
# Std of u: 7.477
# Mean of v: -445.343
# Std of v: 79.768
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 3.987
# Std of u: 8.483
# Mean of v: -432.117
# Std of v: 82.924
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -1.020
# Std of u: 7.283
# Mean of v: -433.178
# Std of v: 78.863
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 2.981
# Std of u: 7.766
# Mean of v: -435.069
# Std of v: 78.733
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 2.308
# Std of u: 7.792
# Mean of v: -438.923
# Std of v: 77.884
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 1.976
# Std of u: 8.917
# Mean of v: -435.605
# Std of v: 77.355
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -1.143
# Std of u: 7.081
# Mean of v: -427.919
# Std of v: 82.238
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 3.089
# Std of u: 8.253
# Mean of v: -423.449
# Std of v: 75.677
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 3.592
# Std of u: 7.941
# Mean of v: -428.530
# Std of v: 74.825
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 5.945
# Std of u: 8.759
# Mean of v: -425.603
# Std of v: 79.522
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 1.494
# Std of u: 7.101
# Mean of v: -445.964
# Std of v: 82.697
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 5.891
# Std of u: 9.050
# Mean of v: -430.853
# Std of v: 79.245
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 3.924
# Std of u: 8.433
# Mean of v: -440.329
# Std of v: 78.211
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -0.285
# Std of u: 7.315
# Mean of v: -436.501
# Std of v: 80.608
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 1.218
# Std of u: 7.484
# Mean of v: -434.397
# Std of v: 80.798
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -4.276
# Std of u: 8.209
# Mean of v: -422.043
# Std of v: 74.878
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -1.789
# Std of u: 6.742
# Mean of v: -435.446
# Std of v: 76.539
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -6.932
# Std of u: 8.502
# Mean of v: -440.385
# Std of v: 75.592
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 4.237
# Std of u: 8.699
# Mean of v: -429.754
# Std of v: 76.656
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 4.391
# Std of u: 9.556
# Mean of v: -429.730
# Std of v: 71.553
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -0.028
# Std of u: 7.425
# Mean of v: -428.486
# Std of v: 77.398
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 3.147
# Std of u: 8.079
# Mean of v: -423.638
# Std of v: 76.488
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -0.431
# Std of u: 7.322
# Mean of v: -431.338
# Std of v: 82.529
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -0.536
# Std of u: 7.206
# Mean of v: -425.816
# Std of v: 82.580
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 3.287
# Std of u: 9.139
# Mean of v: -432.093
# Std of v: 74.458
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -0.600
# Std of u: 6.816
# Mean of v: -426.660
# Std of v: 78.353
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 6.289
# Std of u: 8.847
# Mean of v: -419.784
# Std of v: 74.675
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 1.643
# Std of u: 7.439
# Mean of v: -428.437
# Std of v: 78.837
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 5.233
# Std of u: 8.373
# Mean of v: -429.266
# Std of v: 76.901
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -5.469
# Std of u: 7.577
# Mean of v: -423.611
# Std of v: 79.890
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 0.267
# Std of u: 8.219
# Mean of v: -430.060
# Std of v: 74.611
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 1.965
# Std of u: 7.460
# Mean of v: -431.892
# Std of v: 81.661
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -0.268
# Std of u: 7.086
# Mean of v: -442.295
# Std of v: 85.948
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -1.002
# Std of u: 7.906
# Mean of v: -415.828
# Std of v: 73.036
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 3.338
# Std of u: 8.332
# Mean of v: -425.394
# Std of v: 81.645
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 3.500
# Std of u: 7.991
# Mean of v: -425.999
# Std of v: 77.111
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 1.760
# Std of u: 7.848
# Mean of v: -424.982
# Std of v: 73.166
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 2.622
# Std of u: 8.907
# Mean of v: -412.724
# Std of v: 77.444
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 4.665
# Std of u: 8.599
# Mean of v: -424.368
# Std of v: 81.038
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 6.755
# Std of u: 8.570
# Mean of v: -421.044
# Std of v: 81.445
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 0.838
# Std of u: 7.168
# Mean of v: -421.842
# Std of v: 82.200
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 1.893
# Std of u: 8.457
# Mean of v: -428.900
# Std of v: 80.187
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 2.464
# Std of u: 7.851
# Mean of v: -405.390
# Std of v: 70.228
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -6.480
# Std of u: 7.314
# Mean of v: -421.278
# Std of v: 68.516
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 0.640
# Std of u: 8.025
# Mean of v: -441.781
# Std of v: 85.770
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -2.426
# Std of u: 8.151
# Mean of v: -463.698
# Std of v: 86.894
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 0.316
# Std of u: 7.751
# Mean of v: -426.833
# Std of v: 78.741
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 1.458
# Std of u: 7.605
# Mean of v: -448.018
# Std of v: 87.368
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -1.844
# Std of u: 6.632
# Mean of v: -439.622
# Std of v: 80.706
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 0.721
# Std of u: 7.901
# Mean of v: -419.133
# Std of v: 74.950
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -0.499
# Std of u: 7.476
# Mean of v: -421.324
# Std of v: 71.152
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 3.431
# Std of u: 7.914
# Mean of v: -428.657
# Std of v: 81.698
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 0.526
# Std of u: 8.042
# Mean of v: -426.237
# Std of v: 79.791
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -3.254
# Std of u: 7.237
# Mean of v: -422.164
# Std of v: 79.412
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -0.517
# Std of u: 8.281
# Mean of v: -428.846
# Std of v: 80.261
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -2.003
# Std of u: 6.525
# Mean of v: -428.555
# Std of v: 81.219
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 2.266
# Std of u: 7.559
# Mean of v: -433.032
# Std of v: 81.968
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 0.091
# Std of u: 7.635
# Mean of v: -432.293
# Std of v: 77.548
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -2.640
# Std of u: 7.119
# Mean of v: -434.117
# Std of v: 79.332
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 2.881
# Std of u: 9.008
# Mean of v: -430.060
# Std of v: 82.167
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 2.445
# Std of u: 7.788
# Mean of v: -433.290
# Std of v: 82.530
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 7.298
# Std of u: 10.276
# Mean of v: -428.071
# Std of v: 77.531
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -0.832
# Std of u: 11.692
# Mean of v: -432.516
# Std of v: 82.404
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 0.565
# Std of u: 7.567
# Mean of v: -431.785
# Std of v: 82.860
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 0.720
# Std of u: 6.898
# Mean of v: -430.242
# Std of v: 84.963
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 2.065
# Std of u: 7.512
# Mean of v: -438.980
# Std of v: 82.094
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -1.676
# Std of u: 7.958
# Mean of v: -438.863
# Std of v: 75.349
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -2.400
# Std of u: 6.865
# Mean of v: -434.871
# Std of v: 82.510
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 2.438
# Std of u: 7.251
# Mean of v: -441.668
# Std of v: 81.365
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 1.461
# Std of u: 7.407
# Mean of v: -442.105
# Std of v: 75.530
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 4.796
# Std of u: 8.092
# Mean of v: -436.572
# Std of v: 78.844
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -1.363
# Std of u: 7.982
# Mean of v: -437.049
# Std of v: 80.854
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -0.556
# Std of u: 7.234
# Mean of v: -433.127
# Std of v: 77.656
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -0.736
# Std of u: 7.670
# Mean of v: -429.657
# Std of v: 74.319
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -2.483
# Std of u: 7.207
# Mean of v: -426.731
# Std of v: 79.791
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 0.746
# Std of u: 7.945
# Mean of v: -438.506
# Std of v: 73.057
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 6.341
# Std of u: 9.625
# Mean of v: -420.463
# Std of v: 78.796
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 5.512
# Std of u: 8.504
# Mean of v: -439.247
# Std of v: 80.878
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 1.183
# Std of u: 7.498
# Mean of v: -429.396
# Std of v: 77.585
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -0.288
# Std of u: 7.126
# Mean of v: -440.098
# Std of v: 81.211
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 3.200
# Std of u: 8.071
# Mean of v: -437.831
# Std of v: 82.211
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -0.322
# Std of u: 7.213
# Mean of v: -440.595
# Std of v: 77.786
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 0.418
# Std of u: 8.084
# Mean of v: -428.178
# Std of v: 77.782
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 2.818
# Std of u: 8.784
# Mean of v: -427.058
# Std of v: 78.496
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 1.904
# Std of u: 7.285
# Mean of v: -433.437
# Std of v: 78.640
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -1.830
# Std of u: 7.156
# Mean of v: -440.990
# Std of v: 79.188
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -0.281
# Std of u: 7.124
# Mean of v: -421.718
# Std of v: 68.913
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 1.739
# Std of u: 6.919
# Mean of v: -418.813
# Std of v: 69.394
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -4.068
# Std of u: 7.851
# Mean of v: -434.088
# Std of v: 80.580
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 1.586
# Std of u: 7.973
# Mean of v: -420.430
# Std of v: 74.424
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 4.203
# Std of u: 8.165
# Mean of v: -431.827
# Std of v: 75.692
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 1.459
# Std of u: 7.160
# Mean of v: -438.839
# Std of v: 80.161
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -0.796
# Std of u: 7.435
# Mean of v: -444.000
# Std of v: 83.516
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 3.455
# Std of u: 8.242
# Mean of v: -424.259
# Std of v: 73.784
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 1.411
# Std of u: 7.447
# Mean of v: -439.693
# Std of v: 81.823
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 3.231
# Std of u: 7.472
# Mean of v: -429.378
# Std of v: 75.932
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: 1.270
# Std of u: 7.830
# Mean of v: -421.024
# Std of v: 76.770
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# Number of invalid vectors: 0
# Mean of u: -1.081
# Std of u: 7.005
# Mean of v: -422.553
# Std of v: 77.899
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0003
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-1000, 0]
# transpose: False
# crop: [0, 0, 408, 0]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp31
# No such file: C:\Users\yj\Dropbox (Harvard University)\Riblet\data\piv-data\2021-03-02\0302_Exp31\frame_000202.tiff
# No such file: C:\Users\yj\Dropbox (Harvard University)\Riblet\data\piv-data\2021-03-02\0302_Exp31\frame_000203.tiff
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-504adf9c7a19> in <module>
#      16
#      17 for i in range(N):
# ---> 18     x,y,U,V = pi.quick_piv(search_dict,index_a = ind,index_b = ind+1)
#      19     entire_U.append(U)
#      20     entire_V.append(V)
#
# ~\Documents\GitHub\piv_recipes\openpiv_recipes.py in quick_piv(self, search_dict, index_a, index_b, folder)
#     164
#     165         if folder == None:
# --> 166             img_a, img_b = self.read_two_images(search_dict,index_a=index_a,index_b=index_b)
#     167
#     168             location_path = [x['path'] for x in self.piv_dict_list if search_dict.items() <= x.items()]
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
pi.point_statistics(entire_U,entire_V,25,25,dt=0.1)

# %%
piv_cond = {
    "winsize": 28, "searchsize": 34, "overlap": 24,
    "pixel_density": 47,"scale_factor": 3e4, "arrow_width": 0.001,
    "u_bound": [-50,50],"v_bound": [-550,0],
    "transpose": False, "show_result": False, "crop": [70,70,500,50],
    "sn_threshold": 1.000001,'dt': 0.0001,
    "rotate": 0.25, "save_result": False
}
pi.set_piv_param(piv_cond)

# %%
import os
import time

t = time.time()

paths = ['0302_Exp18',
 '0302_Exp19', 
 '0302_Exp20',
 '0302_Exp21',
 '0302_Exp22',
 '0302_Exp23',
 '0302_Exp24',
 '0302_Exp25', 
 '0302_Exp28',
 '0302_Exp29',
]

for x in paths:
    search_dict = {'path': x}
    proper_index_a = pi.check_proper_index(search_dict,index_a = 3)
    pi.piv_over_time(search_dict,start_index = proper_index_a,N = 95)    
    
elapsed = time.time() - t
print('Elapsed time:', elapsed)
# Out:
# ize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: -10.030
# Std of u: 23.382
# Mean of v: -17.682
# Std of v: 10.494
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: -4.730
# Std of u: 23.690
# Mean of v: -26.117
# Std of v: 9.696
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: -5.177
# Std of u: 15.576
# Mean of v: -17.715
# Std of v: 7.912
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: 8.974
# Std of u: 16.998
# Mean of v: -31.464
# Std of v: 15.180
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: -4.800
# Std of u: 20.306
# Mean of v: -15.946
# Std of v: 8.705
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: 7.108
# Std of u: 17.242
# Mean of v: -28.043
# Std of v: 26.637
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: -3.420
# Std of u: 22.838
# Mean of v: -11.066
# Std of v: 6.574
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: -16.215
# Std of u: 15.191
# Mean of v: -14.920
# Std of v: 7.872
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: -18.461
# Std of u: 14.479
# Mean of v: -20.686
# Std of v: 17.248
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: 11.456
# Std of u: 20.009
# Mean of v: -18.573
# Std of v: 9.105
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: -10.920
# Std of u: 22.364
# Mean of v: -14.336
# Std of v: 6.948
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: -3.929
# Std of u: 15.938
# Mean of v: -17.107
# Std of v: 13.573
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: 1.682
# Std of u: 22.144
# Mean of v: -23.676
# Std of v: 15.923
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: -1.388
# Std of u: 15.066
# Mean of v: -17.089
# Std of v: 10.179
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: -0.488
# Std of u: 17.219
# Mean of v: -18.716
# Std of v: 7.681
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: -18.225
# Std of u: 13.497
# Mean of v: -29.088
# Std of v: 14.411
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: -2.592
# Std of u: 18.133
# Mean of v: -21.366
# Std of v: 9.689
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: -3.615
# Std of u: 11.405
# Mean of v: -15.484
# Std of v: 9.967
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: 10.834
# Std of u: 16.014
# Mean of v: -19.631
# Std of v: 11.830
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: 1.068
# Std of u: 19.414
# Mean of v: -20.020
# Std of v: 7.398
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: 8.149
# Std of u: 15.973
# Mean of v: -28.109
# Std of v: 15.899
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: 2.696
# Std of u: 15.057
# Mean of v: -20.645
# Std of v: 15.338
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: 8.055
# Std of u: 18.030
# Mean of v: -33.497
# Std of v: 29.034
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: 3.721
# Std of u: 19.083
# Mean of v: -14.198
# Std of v: 7.465
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: 8.484
# Std of u: 11.086
# Mean of v: -19.734
# Std of v: 14.982
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: -9.161
# Std of u: 20.013
# Mean of v: -34.236
# Std of v: 17.862
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: 1.454
# Std of u: 21.107
# Mean of v: -23.138
# Std of v: 13.822
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: -8.755
# Std of u: 19.709
# Mean of v: -21.633
# Std of v: 10.549
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: -11.931
# Std of u: 19.023
# Mean of v: -31.696
# Std of v: 27.997
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: 15.772
# Std of u: 14.624
# Mean of v: -24.217
# Std of v: 14.816
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: 1.288
# Std of u: 19.265
# Mean of v: -21.266
# Std of v: 12.744
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: 6.835
# Std of u: 16.253
# Mean of v: -31.636
# Std of v: 35.890
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: 1.046
# Std of u: 23.127
# Mean of v: -11.635
# Std of v: 8.526
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: 15.618
# Std of u: 20.859
# Mean of v: -25.597
# Std of v: 16.162
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: 20.226
# Std of u: 13.873
# Mean of v: -13.665
# Std of v: 12.495
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: 2.507
# Std of u: 17.219
# Mean of v: -36.698
# Std of v: 16.981
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: -13.603
# Std of u: 21.287
# Mean of v: -18.136
# Std of v: 8.263
# - PIV parameters -
# winsize: 28
# searchsize: 34
# overlap: 24
# dt: 0.0001
# image_check: False
# show_vertical_profiles: False
# figure_export_name: _quick_piv.tiff
# text_export_name: _quick_piv.txt
# scale_factor: 30000.0
# pixel_density: 47
# arrow_width: 0.001
# show_result: False
# u_bound: [-50, 50]
# v_bound: [-550, 0]
# transpose: False
# crop: [70, 70, 500, 50]
# sn_threshold: 1.000001
# rotate: 0.25
# save_result: False
# Read image from: 0302_Exp29
# Number of invalid vectors: 0
# Mean of u: -10.972
# Std of u: 18.946
# Mean of v: -35.730
# Std of v: 39.082
# Elapsed time: 361.8959586620331

# %%
for x in paths:
    search_dict = {'path': x}
    pi.point_statistics(search_dict,3,3,0.1)
# Out:
# C:\Users\yj\Dropbox (Harvard University)\Riblet\data\piv-results\2021-03-02\0302_Exp18\entire_U.txt
# # Array shape: (18, 16)
#
# C:\Users\yj\Dropbox (Harvard University)\Riblet\data\piv-results\2021-03-02\0302_Exp19\entire_U.txt
# # Array shape: (18, 16)
#
# C:\Users\yj\Dropbox (Harvard University)\Riblet\data\piv-results\2021-03-02\0302_Exp20\entire_U.txt
# # Array shape: (18, 16)
#
# C:\Users\yj\Dropbox (Harvard University)\Riblet\data\piv-results\2021-03-02\0302_Exp21\entire_U.txt
# # Array shape: (18, 16)
#
# C:\Users\yj\Dropbox (Harvard University)\Riblet\data\piv-results\2021-03-02\0302_Exp22\entire_U.txt
# # Array shape: (18, 16)
#
# C:\Users\yj\Dropbox (Harvard University)\Riblet\data\piv-results\2021-03-02\0302_Exp23\entire_U.txt
# # Array shape: (18, 16)
#
# C:\Users\yj\Dropbox (Harvard University)\Riblet\data\piv-results\2021-03-02\0302_Exp24\entire_U.txt
# # Array shape: (18, 16)
#
# C:\Users\yj\Dropbox (Harvard University)\Riblet\data\piv-results\2021-03-02\0302_Exp25\entire_U.txt
# # Array shape: (18, 16)
#
# C:\Users\yj\Dropbox (Harvard University)\Riblet\data\piv-results\2021-03-02\0302_Exp28\entire_U.txt
# # Array shape: (18, 16)
#
# C:\Users\yj\Dropbox (Harvard University)\Riblet\data\piv-results\2021-03-02\0302_Exp29\entire_U.txt
# # Array shape: (18, 16)

# %%
'0302_Exp26','0302_Exp27', '0302_Exp30',
 '0302_Exp31'
